# %%
import pandas as pd
pf = pd.read_csv('C:\\Users\\golen\\OneDrive\\Documents\\DATA CHALLENGES\\dATASETS\\June 2022 - Forbes Worlds Billionaires.csv')
# pd.options.display.max_rows = None
pf.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automotive       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# 2       Fashion & Retail                LVMH         France         NaN  ...
# 3             Technology           Microsoft  United States  Washington  ...
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska  ...
#
#                        organization selfMade gender   birthDate  \
# ...

# %% [markdown]
# Sorting countries based on count of Billionaires in descending orders.

# %%
def values(v):
    return v[1]

g = pf.groupby("country")
print(g)
d = {}
for c,info in g:
    d [c] = info.shape[0]
    
print(d)
l = sorted(d.items(),reverse = True,key=values)
l

# %%
d = pf.groupby("country")
pd.options.display.max_rows = 4000
d.get_group("India")[pf["category"] == "Technology"].iloc[:,0].value_counts()
#d.get_group("India")[d["Category"] == "Technology"]
# Out:
# C:\Users\golen\AppData\Local\Temp\ipykernel_6296\1496750225.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   d.get_group("India")[pf["category"] == "Technology"].iloc[:,0].value_counts()
# 2190    3
# 47      1
# 206     1
# 654     1
# 709     1
# 822     1
# 883     1
# 1096    1
# 1196    1
# 1397    1
# 1729    1
# 2324    1
# 2448    1
# Name: rank, dtype: int64

# %% [markdown]
# frequency of a value in a column using value_counts()

# %%
pd.options.display.max_rows = 4000

pf.loc[:,"country"].value_counts()
# Out:
# United States               748
# China                       571
# India                       159
# Germany                     112
# United Kingdom               85
# Switzerland                  73
# Hong Kong                    68
# Russia                       65
# Brazil                       54
# Italy                        49
# Canada                       45
# South Korea                  43
# Taiwan                       42
# Australia                    41
# Japan                        38
# Singapore                    35
# France                       34
# Sweden                       32
# Indonesia                    27
# Thailand                     27
# Spain                        25
# Israel                       24
# Turkey                       23
# Philippines                  19
# Malaysia                     15
# Mexico                       14
# Monaco                       13
# Austria                      12
# United Arab Emirates         10
# ...

# %%
pf.iloc[:,[0,1,2,3]]
# Out:
#       rank                                  personName    age  finalWorth
# 0        1                                   Elon Musk   50.0    219000.0
# 1        2                                  Jeff Bezos   58.0    171000.0
# 2        3                    Bernard Arnault & family   73.0    158000.0
# 3        4                                  Bill Gates   66.0    129000.0
# 4        5                              Warren Buffett   91.0    118000.0
# 5        6                                  Larry Page   49.0    111000.0
# 6        7                                 Sergey Brin   48.0    107000.0
# 7        8                               Larry Ellison   77.0    106000.0
# 8        9                               Steve Ballmer   66.0     91400.0
# 9       10                               Mukesh Ambani   64.0     90700.0
# 10      11                       Gautam Adani & family   59.0     90000.0
# 11      12                           Michael Bloomberg   80.0     82000.0
# ...

# %%
import numpy as np
d = pf.groupby('country')
df_india_Tech = d.get_group("India")[pf["category"]=="Technology"]
df_Usa_Tech = d.get_group("United States")[pf["category"]=="Technology"]
df_Tech = pd.concat([df_india_Tech,df_Usa_Tech],ignore_index = True)
df = pf.loc[np.logical_and(pf["category"]=="Technology",np.logical_or(pf["country"]=="India",pf["country"]=="United States"))]
df
# Out:
# C:\Users\golen\AppData\Local\Temp\ipykernel_6296\4159562334.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_india_Tech = d.get_group("India")[pf["category"]=="Technology"]
# C:\Users\golen\AppData\Local\Temp\ipykernel_6296\4159562334.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_Usa_Tech = d.get_group("United States")[pf["category"]=="Technology"]
#       rank                           personName   age  finalWorth  year  \
# 1        2                           Jeff Bezos  58.0    171000.0  2022
# 3        4                           Bill Gates  66.0    129000.0  2022
# 5        6                           Larry Page  49.0    111000.0  2022
# 6        7                          Sergey Brin  48.0    107000.0  2022
# 7        8                        Larry Ellison  77.0    106000.0  2022
# 8        9                        Steve Ballmer  66.0     91400.0  2022
# ...

# %%
import numpy as np
df = pf.loc[np.logical_and(pf["category"]=="Technology",np.logical_or(pf["country"]=="India",pf["country"]=="United States"))]
df.head
# Out:
# <bound method NDFrame.head of       rank                           personName   age  finalWorth  year  \
# 1        2                           Jeff Bezos  58.0    171000.0  2022
# 3        4                           Bill Gates  66.0    129000.0  2022
# 5        6                           Larry Page  49.0    111000.0  2022
# 6        7                          Sergey Brin  48.0    107000.0  2022
# 7        8                        Larry Ellison  77.0    106000.0  2022
# 8        9                        Steve Ballmer  66.0     91400.0  2022
# 14      15                      Mark Zuckerberg  37.0     67300.0  2022
# 23      24                         Michael Dell  57.0     55100.0  2022
# 29      30                      MacKenzie Scott  51.0     43600.0  2022
# 46      47                           Shiv Nadar  76.0     28700.0  2022
# 69      70                         Eric Schmidt  66.0     22100.0  2022
# 77      78                         Jensen Huang  59.0     20600.0  2022
# ...

# %%
import pandas as pd
import numpy as np
from joblib import Parallel, delayed
import time

# %%
#Generating a dummy data and converting it into dataframe
start = time.time()
values = np.random.uniform(size=(20000,25))
df = pd.DataFrame(values)
end = time.time()
print(end - start)
df
# Out:
# 0.00798344612121582
#              0         1         2         3         4         5         6   \
# 0      0.928464  0.880305  0.579522  0.311685  0.219952  0.011934  0.085032
# 1      0.634204  0.261614  0.405917  0.405489  0.534870  0.191959  0.503157
# 2      0.730433  0.568280  0.974591  0.133013  0.447040  0.122955  0.725577
# 3      0.367679  0.136018  0.077831  0.555823  0.921219  0.044755  0.485928
# 4      0.754000  0.863634  0.816159  0.488000  0.347493  0.825502  0.610670
# ...         ...       ...       ...       ...       ...       ...       ...
# 19995  0.691371  0.842739  0.590845  0.426919  0.020080  0.016326  0.314283
# 19996  0.672226  0.666950  0.331248  0.657051  0.650388  0.798520  0.451955
# 19997  0.294048  0.845140  0.734627  0.065063  0.094618  0.428162  0.529856
# 19998  0.124636  0.229789  0.112939  0.783799  0.080259  0.785847  0.602050
# 19999  0.645707  0.849925  0.976196  0.772222  0.710398  0.145226  0.851862
#
# ...

# %%
# Generating CSV, Excel, Pickle files with random values 
for file_number in range(10):
    values = np.random.uniform(size=(20000,25))
    pd.DataFrame(values).to_csv(f"Dummy {file_number}.csv")
    pd.DataFrame(values).to_excel(f"Dummy {file_number}.xlsx")
    pd.DataFrame(values).to_pickle(f"Dummy {file_number}.pickle")

# %%
l = []
for i in range(0,10):
    l.append(pd.read_csv(f"Dummy {i}.csv"))
df = pd.concat(l,ignore_index=True)

# %%
df.tail()
# Out:
#         Unnamed: 0         0         1         2         3         4  \
# 199995       19995  0.297412  0.501672  0.061717  0.193558  0.497485
# 199996       19996  0.299990  0.893675  0.871592  0.606461  0.690336
# 199997       19997  0.387434  0.824786  0.382110  0.194453  0.243040
# 199998       19998  0.360870  0.706889  0.380156  0.406674  0.812392
# 199999       19999  0.948565  0.451968  0.008118  0.907026  0.799228
#
#                5         6         7         8  ...        15        16  \
# 199995  0.437673  0.647237  0.587467  0.381899  ...  0.792435  0.188486
# 199996  0.162277  0.738925  0.112027  0.605465  ...  0.859836  0.845726
# 199997  0.567389  0.791882  0.473053  0.253681  ...  0.353968  0.584143
# 199998  0.603164  0.495694  0.068644  0.511933  ...  0.287230  0.453722
# 199999  0.417400  0.228803  0.823762  0.660761  ...  0.847254  0.264705
#
#               17        18        19        20        21        22        23  \
# ...

# %%
import pandas as pd
df = pd.read_csv("stockdata.csv",skiprows  = 3,nrows = 5,names = ["T","ep","rev","pr","people"],na_values = ["not available","n.a.",-1])
df
# Out:
#        T     ep    rev      pr         people
# 0  GOOGL  27.82   87.0   845.0     larry page
# 1    WMT   4.61  484.0    65.0            NaN
# 2   MSFT    NaN   85.0    64.0     bill gates
# 3   RIL     NaN   50.0  1023.0  mukesh ambani
# 4   TATA   5.60    NaN     NaN     ratan tata

# %%
import pandas as pd
dff = pd.read_csv("stockdata.csv",skiprows  = 3,nrows = 5,names = ["T","ep","rev","pr","people"],na_values = {
                                                                                            "ep":["not available","n.a."],
                                                                                            "rev":["not available","n.a.",-1],
                                                                                            "people":["not available","n.a."]})
dff
# Out:
#        T     ep    rev    pr         people
# 0  GOOGL  27.82   87.0   845     larry page
# 1    WMT   4.61  484.0    65            NaN
# 2   MSFT  -1.00   85.0    64     bill gates
# 3   RIL     NaN   50.0  1023  mukesh ambani
# 4   TATA   5.60    NaN  n.a.     ratan tata

# %%
import pandas as pd
df_weather = pd.read_csv("weather.csv",parse_dates = ["day"],na_values = [-99999,0])
df_weather.set_index('day',inplace = True)

df_weather
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02          NaN        7.0  Sunny
# 2017-01-03         28.0        NaN   Snow
# 2017-01-04          NaN        7.0    NaN
# 2017-01-05          NaN        NaN   Rain
# 2017-01-06         31.0        NaN  Sunny
# 2017-01-06         34.0        5.0    NaN

# %%
new = df_weather.fillna(0)
print(new)
print(type(new.event[2]))
print(type(new.event[3]))
type(new.temperature[1])
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02          0.0        7.0  Sunny
# 2017-01-03         28.0        0.0   Snow
# 2017-01-04          0.0        7.0      0
# 2017-01-05          0.0        0.0   Rain
# 2017-01-06         31.0        0.0  Sunny
# 2017-01-06         34.0        5.0      0
# <class 'str'>
# <class 'int'>
# numpy.float64

# %%
new = df_weather.fillna("0")
print(new)
print(type(new.event[2]))
print(type(new.event[3]))
type(new.temperature[2])
# Out:
#            temperature windspeed  event
# day
# 2017-01-01        32.0       6.0   Rain
# 2017-01-02           0       7.0  Sunny
# 2017-01-03        28.0         0   Snow
# 2017-01-04           0       7.0      0
# 2017-01-05           0         0   Rain
# 2017-01-06        31.0         0  Sunny
# 2017-01-06        34.0       5.0      0
# <class 'str'>
# <class 'str'>
# float

# %%
new_solution = df_weather.fillna({"temperature":0.0,
                                  "windspeed":0.0,
                                  "event":"no event"})
new_solution
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-02          0.0        7.0     Sunny
# 2017-01-03         28.0        0.0      Snow
# 2017-01-04          0.0        7.0  no event
# 2017-01-05          0.0        0.0      Rain
# 2017-01-06         31.0        0.0     Sunny
# 2017-01-06         34.0        5.0  no event

# %%
df_weather
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02          NaN        7.0  Sunny
# 2017-01-03         28.0        NaN   Snow
# 2017-01-04          NaN        7.0    NaN
# 2017-01-05          NaN        NaN   Rain
# 2017-01-06         31.0        NaN  Sunny
# 2017-01-06         34.0        5.0    NaN

# %%
prev_value_df = df_weather.fillna(method = "ffill",limit = 1)
prev_value_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02         32.0        7.0  Sunny
# 2017-01-03         28.0        7.0   Snow
# 2017-01-04         28.0        7.0   Snow
# 2017-01-05          NaN        7.0   Rain
# 2017-01-06         31.0        NaN  Sunny
# 2017-01-06         34.0        5.0  Sunny

# %%
next_value_df = df_weather.fillna(method = "bfill")
next_value_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02         28.0        7.0  Sunny
# 2017-01-03         28.0        7.0   Snow
# 2017-01-04         31.0        7.0   Rain
# 2017-01-05         31.0        5.0   Rain
# 2017-01-06         31.0        5.0  Sunny
# 2017-01-06         34.0        5.0    NaN

# %%
#df_weather.set_index('day',inplace = True)#interpolate will not work if we dont set the day column as index
inter_df = df_weather.interpolate()
inter_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0   6.000000   Rain
# 2017-01-02         30.0   7.000000  Sunny
# 2017-01-03         28.0   7.000000   Snow
# 2017-01-04         29.0   7.000000    NaN
# 2017-01-05         30.0   6.333333   Rain
# 2017-01-06         31.0   5.666667  Sunny
# 2017-01-06         34.0   5.000000    NaN

# %%
inter_df = df_weather.interpolate(method = "time")
print(df_weather)
inter_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02          NaN        7.0  Sunny
# 2017-01-03         28.0        NaN   Snow
# 2017-01-04          NaN        7.0    NaN
# 2017-01-05          NaN        NaN   Rain
# 2017-01-06         31.0        NaN  Sunny
# 2017-01-06         34.0        5.0    NaN
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02         30.0        7.0  Sunny
# 2017-01-03         28.0        7.0   Snow
# 2017-01-04         29.0        7.0    NaN
# 2017-01-05         30.0        6.0   Rain
# 2017-01-06         31.0        5.0  Sunny
# 2017-01-06         34.0        5.0    NaN

# %%
drop_df =df_weather
print(df_weather)
drop_df.dropna(how = "all")
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02          NaN        7.0  Sunny
# 2017-01-03         28.0        NaN   Snow
# 2017-01-04          NaN        7.0    NaN
# 2017-01-05          NaN        NaN   Rain
# 2017-01-06         31.0        NaN  Sunny
# 2017-01-06         34.0        5.0    NaN
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02          NaN        7.0  Sunny
# 2017-01-03         28.0        NaN   Snow
# 2017-01-04          NaN        7.0    NaN
# 2017-01-05          NaN        NaN   Rain
# 2017-01-06         31.0        NaN  Sunny
# 2017-01-06         34.0        5.0    NaN

# %%
drop_df =df_weather
print(df_weather)
drop_df.dropna(thresh = 2)
drop_df.index
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02          NaN        7.0  Sunny
# 2017-01-03         28.0        NaN   Snow
# 2017-01-04          NaN        7.0    NaN
# 2017-01-05          NaN        NaN   Rain
# 2017-01-06         31.0        NaN  Sunny
# 2017-01-06         34.0        5.0    NaN
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-06'],
#               dtype='datetime64[ns]', name='day', freq=None)

# %%
dfi = df_weather
dfindex= dfi.reset_index().drop_duplicates(subset='day', keep='last').set_index('day')
dfindex
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02          NaN        7.0  Sunny
# 2017-01-03         28.0        NaN   Snow
# 2017-01-04          NaN        7.0    NaN
# 2017-01-05          NaN        NaN   Rain
# 2017-01-06         34.0        5.0    NaN

# %%
date_range = pd.date_range("01-01-2017","01-11-2017")
date_index = pd.DatetimeIndex(date_range)
dfindex.reindex(date_index)
# Out:
#             temperature  windspeed  event
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02          NaN        7.0  Sunny
# 2017-01-03         28.0        NaN   Snow
# 2017-01-04          NaN        7.0    NaN
# 2017-01-05          NaN        NaN   Rain
# 2017-01-06         34.0        5.0    NaN
# 2017-01-07          NaN        NaN    NaN
# 2017-01-08          NaN        NaN    NaN
# 2017-01-09          NaN        NaN    NaN
# 2017-01-10          NaN        NaN    NaN
# 2017-01-11          NaN        NaN    NaN

# %%
df
# Out:
#        T     ep    rev      pr         people
# 0  GOOGL  27.82   87.0   845.0     larry page
# 1    WMT   4.61  484.0    65.0            NaN
# 2   MSFT    NaN   85.0    64.0     bill gates
# 3   RIL     NaN   50.0  1023.0  mukesh ambani
# 4   TATA   5.60    NaN     NaN     ratan tata

# %%
df_weather
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02          NaN        7.0  Sunny
# 2017-01-03         28.0        NaN   Snow
# 2017-01-04          NaN        7.0    NaN
# 2017-01-05          NaN        NaN   Rain
# 2017-01-06         31.0        NaN  Sunny
# 2017-01-06         34.0        5.0    NaN

# %%
df_r = df_weather.replace({"temperature":np.NaN,
                           "windspeed":np.NaN,
                           "event":np.NaN},0)
df_r
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02          0.0        7.0  Sunny
# 2017-01-03         28.0        0.0   Snow
# 2017-01-04          0.0        7.0      0
# 2017-01-05          0.0        0.0   Rain
# 2017-01-06         31.0        0.0  Sunny
# 2017-01-06         34.0        5.0      0

# %%
df_r = df_weather.replace({"temperature":np.NaN,
                           "windspeed":np.NaN},0)
df_r = df_r.replace({"event":np.NaN},"No Event")
df_r.temperature = df_r.temperature*0.1
df_r
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01          3.2        6.0      Rain
# 2017-01-02          0.0        7.0     Sunny
# 2017-01-03          2.8        0.0      Snow
# 2017-01-04          0.0        7.0  No Event
# 2017-01-05          0.0        0.0      Rain
# 2017-01-06          3.1        0.0     Sunny
# 2017-01-06          3.4        5.0  No Event

# %%
df_r.temperature.values
# Out:
# array([3.2, 0. , 2.8, 0. , 0. , 3.1, 3.4])

# %%
df_Modify = df_r

df_Modify["temp"] = df_Modify.temperature[0:]

df_Modify["temp"] = df_Modify["temp"].astype("string")

df_Modify["event"] = df_Modify["event"].astype("string")

print(df_Modify.dtypes)

print(df_Modify)

for i in range(df_Modify.shape[0]):
    df_Modify["temp"][i] = df_Modify["temp"][i][0:3]
    
df_Modify["temp"] = df_Modify["temp"] + " C"
df_Modify
# Out:
# temperature    float64
# windspeed      float64
# event           string
# temp            string
# dtype: object
#             temperature  windspeed     event                temp
# day
# 2017-01-01          3.2        6.0      Rain                 3.2
# 2017-01-02          0.0        7.0     Sunny                 0.0
# 2017-01-03          2.8        0.0      Snow  2.8000000000000003
# 2017-01-04          0.0        7.0  No Event                 0.0
# 2017-01-05          0.0        0.0      Rain                 0.0
# 2017-01-06          3.1        0.0     Sunny                 3.1
# 2017-01-06          3.4        5.0  No Event  3.4000000000000004
#             temperature  windspeed     event   temp
# day
# 2017-01-01          3.2        6.0      Rain  3.2 C
# 2017-01-02          0.0        7.0     Sunny  0.0 C
# 2017-01-03          2.8        0.0      Snow  2.8 C
# 2017-01-04          0.0        7.0  No Event  0.0 C
# 2017-01-05          0.0        0.0      Rain  0.0 C
# ...

# %% [markdown]
# # Pivot and Pivot Table

# %%
import pandas as pd
df = pd.read_csv("weather1.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index = "city",columns = "date", values = "humidity")
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %%
df1 = pd.read_csv("weather2.csv")
df1
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
df1.pivot_table(index = "city",columns = "date",aggfunc = "mean",margins = True)
# Out:
#          humidity                 temperature
# date     5/1/2017 5/2/2017    All    5/1/2017 5/2/2017     All
# city
# mumbai      81.50    55.50  68.50       76.50     81.0  78.750
# new york    55.00    61.00  58.00       63.00     71.0  67.000
# All         68.25    58.25  63.25       69.75     76.0  72.875

# %%
df2 = pd.read_csv("weather3.csv")
df2
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %%
type(df2.date[0])
# Out:
# str

# %%
df2["date"] = pd.to_datetime(df2["date"])
type(df2.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#aggregate by month
df2.pivot_table(index = pd.Grouper(freq = "M",key = "date"),columns = "city")
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667
